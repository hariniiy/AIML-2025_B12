# %% [markdown]
# <a href="https://colab.research.google.com/github/hariniiy/AIML-2025_B12/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list=[1,2,3,4,5]
print("List:",list)
#2
array1=np.array([1,2,3,4,5])
array2=np.array([6,7,8,9,10])
print("Array1:",array1)
print("Array2:",array2)
#3
print("Type of my list:",type(list))
#4
a=array1+array2
print("Addition:",a)
b=array1-array2
print("Subtraction:",b)
c=array1*array2
print("Multiplication:",c)
d=array1/array2
print("Division:",d)
#5
addition_result=array1+array2
print(f"Addition of two arrays:array1+array2={addition_result}")
#6
sin_values=np.sin(array1)
print("Sine of array1:",sin_values)
log_values=np.log(array1)
print("Log of array1:",log_values)
exp_values=np.exp(array1)
print("Exponential of array1:",exp_values)
import numpy as np
list=[1,2,3,4,5]
print("List:",list)
#2
array1=np.array([1,2,3,4,5])
array2=np.array([6,7,8,9,10])
print("Array1:",array1)
print("Array2:",array2)
#3
print("Type of my list:",type(list))
#4
a=array1+array2
print("Addition:",a)
b=array1-array2
print("Subtraction:",b)
c=array1*array2
print("Multiplication:",c)
d=array1/array2
print("Division:",d)
#5
addition_result=array1+array2
print(f"Addition of two arrays:array1+array2={addition_result}")
#6
sin_values=np.sin(array1)
print("Sine of array1:",sin_values)
log_values=np.log(array1)
print("Log of array1:",log_values)
exp_values=np.exp(array1)
print("Exponential of array1:",exp_values)
[8:52 PM, 8/19/2024] Gayathri: people = ['kiran','arun','vijay','varun']
ages=["25,30,35,40"]
height=[145,151,165,173]
weight=[45,55,65,75]
import matplotlib.pyplot as plt
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()
#4
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()
#5
import numpy as np
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.show()
