# %% [markdown]
# <a href="https://colab.research.google.com/github/hariniiy/AIML-2025_B12/blob/main/AIML_A1_LAB1_PART3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART 3**

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd
import requests

# Replace with the raw URL of your file on GitHub
url = "https://github.com/2303A51795/AIML-2025-B12/blob/main/Lab01-Text.txt"

response = requests.get(url)
response.raise_for_status()  # Raise an exception if there's an error fetching the file

# Assuming the file is a text file, you can read it directly into pandas
from io import StringIO
df1 = pd.read_table(StringIO(response.text))

print(df1.head())  # Display the first few rows of the DataFrame
# Out:
#                                      <!DOCTYPE html>
# 0                                              <html
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...
# 3    data-a11y-animated-images="system" data-a11y...
# 4                                                  >

# %%
df1
# Out:
#                                         <!DOCTYPE html>
# 0                                                 <html
# 1                                             lang="en"
# 2       data-color-mode="auto" data-light-theme="lig...
# 3       data-a11y-animated-images="system" data-a11y...
# 4                                                     >
# ...                                                 ...
# 1356                                             </div>
# 1357      <div id="js-global-screen-reader-notice" c...
# 1358      <div id="js-global-screen-reader-notice-as...
# 1359                                            </body>
# 1360                                            </html>
#
# [1361 rows x 1 columns]

# %%
data2 = pd.read_csv("Lab01-Text.csv")

# %%
data2

# %%
data3 = pd.read_excel("Height_weight.xlsx")
